# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
print(len(coordinates))
# Out:
# 1500

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0cfb5300697071d89717e2532a6fd122

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0cfb5300697071d89717e2532a6fd122&q=Boston

# %%
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02n"}],"base":"stations","main":{"temp":45.63,"feels_like":40.08,"temp_min":43.32,"temp_max":47.17,"pressure":1013,"humidity":34},"visibility":10000,"wind":{"speed":11.5,"deg":320,"gust":20.71},"clouds":{"all":20},"dt":1651198429,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1651139008,"sunset":1651189183},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 45.63,
#   'feels_like': 40.08,
#   'temp_min': 43.32,
#   'temp_max': 47.17,
#   'pressure': 1013,
#   'humidity': 34},
#  'visibility': 10000,
#  'wind': {'speed': 11.5, 'deg': 320, 'gust': 20.71},
#  'clouds': {'all': 20},
#  'dt': 1651198429,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1651139008,
#   'sunset': 1651189183},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0cfb5300697071d89717e2532a6fd122&q=Bston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 45.63,
#   'feels_like': 40.08,
#   'temp_min': 43.32,
#   'temp_max': 47.17,
#   'pressure': 1013,
#   'humidity': 34},
#  'visibility': 10000,
#  'wind': {'speed': 11.5, 'deg': 320, 'gust': 20.71},
#  'clouds': {'all': 20},
#  'dt': 1651198429,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1651139008,
#   'sunset': 1651189183},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 47.17 34 20 11.5

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 4, 29, 2, 13, 49)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
import pandas as pd
from citipy import citipy

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Create a list for holding the cities. 
cities = [] 
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name 
# If the city is unique, then we will add it to the cities list. 
    if city not in cities: cities.append(city)
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
print(len(cities))
# Out:
# 598

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | vidim
# Processing Record 2 of Set 1 | rio grande
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | lewiston
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | fairbanks
# Processing Record 9 of Set 1 | clyde river
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | tyukhtet
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | katsuura
# Processing Record 14 of Set 1 | isangel
# Processing Record 15 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 1 | phan thiet
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | kargasok
# Processing Record 20 of Set 1 | gornozavodsk
# Processing Record 21 of Set 1 | sakakah
# Processing Record 22 of Set 1 | niamey
# Processing Record 23 of Set 1 | svetogorsk
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | santiago de chuco
# Processing Record 26 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | ouranopolis
# City not found. Skipping...
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | pinheiro machado
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | ust-kuyga
# Processing Record 34 of Set 1 | divnomorskoye
# Processing Record 35 of Set 1 | chokurdakh
# Processing Record 36 of Set 1 | sinnamary
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | auriflama
# Processing Record 39 of Set 1 | guaratinga
# Processing Record 40 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 1 | chinsali
# Processing Record 42 of Set 1 | ipixuna
# Processing Record 43 of Set 1 | srednekolymsk
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | kahului
# Processing Record 47 of Set 1 | kemijarvi
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 1 | port hardy
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | ohaeawai
# Processing Record 4 of Set 2 | tiarei
# Processing Record 5 of Set 2 | megion
# Processing Record 6 of Set 2 | pochutla
# Processing Record 7 of Set 2 | basco
# Processing Record 8 of Set 2 | meulaboh
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | mwinilunga
# Processing Record 11 of Set 2 | son la
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | killybegs
# Processing Record 16 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 2 | saldanha
# Processing Record 18 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 2 | hamburg
# Processing Record 20 of Set 2 | elliot lake
# Processing Record 21 of Set 2 | kupang
# Processing Record 22 of Set 2 | vrangel
# Processing Record 23 of Set 2 | hamilton
# Processing Record 24 of Set 2 | vardo
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | asau
# Processing Record 27 of Set 2 | sao joao da barra
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | hithadhoo
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 2 | destin
# Processing Record 33 of Set 2 | lavrentiya
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | waipawa
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | point fortin
# Processing Record 41 of Set 2 | belaya gora
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | ponta do sol
# Processing Record 44 of Set 2 | virginia beach
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | kaitangata
# Processing Record 50 of Set 2 | camocim
# Processing Record 1 of Set 3 | cabo san lucas
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | grindavik
# Processing Record 4 of Set 3 | belle fourche
# Processing Record 5 of Set 3 | saint-philippe
# Processing Record 6 of Set 3 | sherman
# Processing Record 7 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | nienburg
# Processing Record 11 of Set 3 | yar-sale
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | owando
# Processing Record 14 of Set 3 | pishin
# Processing Record 15 of Set 3 | alyangula
# Processing Record 16 of Set 3 | cervo
# Processing Record 17 of Set 3 | chapais
# Processing Record 18 of Set 3 | pueblo
# Processing Record 19 of Set 3 | burlington
# Processing Record 20 of Set 3 | markova
# Processing Record 21 of Set 3 | leczna
# Processing Record 22 of Set 3 | jiangyou
# Processing Record 23 of Set 3 | mazagao
# Processing Record 24 of Set 3 | high level
# Processing Record 25 of Set 3 | hofn
# Processing Record 26 of Set 3 | tura
# Processing Record 27 of Set 3 | vaini
# Processing Record 28 of Set 3 | georgetown
# Processing Record 29 of Set 3 | esperance
# Processing Record 30 of Set 3 | amurzet
# Processing Record 31 of Set 3 | diffa
# Processing Record 32 of Set 3 | batsfjord
# Processing Record 33 of Set 3 | el dorado
# Processing Record 34 of Set 3 | kollam
# Processing Record 35 of Set 3 | lahaina
# Processing Record 36 of Set 3 | bantou
# Processing Record 37 of Set 3 | praia da vitoria
# Processing Record 38 of Set 3 | mehran
# Processing Record 39 of Set 3 | evensk
# Processing Record 40 of Set 3 | nhulunbuy
# Processing Record 41 of Set 3 | tarsus
# Processing Record 42 of Set 3 | codrington
# Processing Record 43 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | dinga
# Processing Record 46 of Set 3 | mayahi
# Processing Record 47 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 3 | wufeng
# Processing Record 49 of Set 3 | calgary
# Processing Record 50 of Set 3 | duz
# City not found. Skipping...
# Processing Record 1 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 2 of Set 4 | hovd
# Processing Record 3 of Set 4 | alpena
# Processing Record 4 of Set 4 | guatire
# Processing Record 5 of Set 4 | payo
# Processing Record 6 of Set 4 | bathsheba
# Processing Record 7 of Set 4 | hobart
# Processing Record 8 of Set 4 | pacifica
# Processing Record 9 of Set 4 | kinango
# Processing Record 10 of Set 4 | hilo
# Processing Record 11 of Set 4 | bosaso
# Processing Record 12 of Set 4 | avarua
# Processing Record 13 of Set 4 | lebu
# Processing Record 14 of Set 4 | kavieng
# Processing Record 15 of Set 4 | okhotsk
# Processing Record 16 of Set 4 | cabedelo
# Processing Record 17 of Set 4 | raudeberg
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | ovalle
# Processing Record 20 of Set 4 | baclesu
# City not found. Skipping...
# Processing Record 21 of Set 4 | boyolangu
# Processing Record 22 of Set 4 | maceio
# Processing Record 23 of Set 4 | palana
# Processing Record 24 of Set 4 | maraba
# Processing Record 25 of Set 4 | kenmare
# Processing Record 26 of Set 4 | weston
# Processing Record 27 of Set 4 | kruisfontein
# Processing Record 28 of Set 4 | gillette
# Processing Record 29 of Set 4 | malatya
# Processing Record 30 of Set 4 | baghdad
# Processing Record 31 of Set 4 | tessalit
# Processing Record 32 of Set 4 | victor harbor
# Processing Record 33 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 34 of Set 4 | san patricio
# Processing Record 35 of Set 4 | stawell
# Processing Record 36 of Set 4 | marawi
# Processing Record 37 of Set 4 | san jose
# Processing Record 38 of Set 4 | abonnema
# Processing Record 39 of Set 4 | pangoa
# Processing Record 40 of Set 4 | haines junction
# Processing Record 41 of Set 4 | fare
# Processing Record 42 of Set 4 | tsienyane
# City not found. Skipping...
# Processing Record 43 of Set 4 | carbonia
# Processing Record 44 of Set 4 | dikson
# Processing Record 45 of Set 4 | angol
# Processing Record 46 of Set 4 | enshi
# Processing Record 47 of Set 4 | aklavik
# Processing Record 48 of Set 4 | acapulco
# Processing Record 49 of Set 4 | ilulissat
# Processing Record 50 of Set 4 | bengkulu
# Processing Record 1 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 5 | husavik
# Processing Record 3 of Set 5 | shimoda
# Processing Record 4 of Set 5 | norman wells
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | kaura namoda
# Processing Record 7 of Set 5 | ilave
# Processing Record 8 of Set 5 | severo-kurilsk
# Processing Record 9 of Set 5 | east london
# Processing Record 10 of Set 5 | leningradskiy
# Processing Record 11 of Set 5 | angoram
# Processing Record 12 of Set 5 | manokwari
# Processing Record 13 of Set 5 | palmer
# Processing Record 14 of Set 5 | upernavik
# Processing Record 15 of Set 5 | nola
# Processing Record 16 of Set 5 | laguna
# Processing Record 17 of Set 5 | baruun-urt
# Processing Record 18 of Set 5 | coari
# Processing Record 19 of Set 5 | selikhino
# Processing Record 20 of Set 5 | marion
# Processing Record 21 of Set 5 | samana
# Processing Record 22 of Set 5 | kysyl-syr
# Processing Record 23 of Set 5 | karasjok
# Processing Record 24 of Set 5 | north myrtle beach
# Processing Record 25 of Set 5 | arrecife
# Processing Record 26 of Set 5 | ballina
# Processing Record 27 of Set 5 | vila franca do campo
# Processing Record 28 of Set 5 | ancud
# Processing Record 29 of Set 5 | turukhansk
# Processing Record 30 of Set 5 | bluff
# Processing Record 31 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 5 | arraial do cabo
# Processing Record 33 of Set 5 | rawson
# Processing Record 34 of Set 5 | baiyin
# Processing Record 35 of Set 5 | kristiansund
# Processing Record 36 of Set 5 | eldorado
# Processing Record 37 of Set 5 | dubuque
# Processing Record 38 of Set 5 | madang
# Processing Record 39 of Set 5 | cookeville
# Processing Record 40 of Set 5 | agua dulce
# Processing Record 41 of Set 5 | wickford
# Processing Record 42 of Set 5 | deputatskiy
# Processing Record 43 of Set 5 | guntakal
# Processing Record 44 of Set 5 | tasiilaq
# Processing Record 45 of Set 5 | provideniya
# Processing Record 46 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 5 | burley
# Processing Record 48 of Set 5 | anadyr
# Processing Record 49 of Set 5 | khatanga
# Processing Record 50 of Set 5 | mahebourg
# Processing Record 1 of Set 6 | christchurch
# Processing Record 2 of Set 6 | sola
# Processing Record 3 of Set 6 | fria
# Processing Record 4 of Set 6 | kieta
# Processing Record 5 of Set 6 | eyl
# Processing Record 6 of Set 6 | beloha
# Processing Record 7 of Set 6 | elat
# Processing Record 8 of Set 6 | airai
# Processing Record 9 of Set 6 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 10 of Set 6 | ronneby
# Processing Record 11 of Set 6 | flinders
# Processing Record 12 of Set 6 | sawakin
# Processing Record 13 of Set 6 | gornopravdinsk
# Processing Record 14 of Set 6 | cherskiy
# Processing Record 15 of Set 6 | kurilsk
# Processing Record 16 of Set 6 | caconda
# Processing Record 17 of Set 6 | bom jesus
# Processing Record 18 of Set 6 | bilma
# Processing Record 19 of Set 6 | broken hill
# Processing Record 20 of Set 6 | bredasdorp
# Processing Record 21 of Set 6 | kodinsk
# Processing Record 22 of Set 6 | tarnogskiy gorodok
# Processing Record 23 of Set 6 | hoi an
# Processing Record 24 of Set 6 | tsabong
# Processing Record 25 of Set 6 | luganville
# Processing Record 26 of Set 6 | nouadhibou
# Processing Record 27 of Set 6 | marang
# Processing Record 28 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 6 | alta floresta
# Processing Record 30 of Set 6 | calama
# Processing Record 31 of Set 6 | port blair
# Processing Record 32 of Set 6 | walvis bay
# Processing Record 33 of Set 6 | vostok
# Processing Record 34 of Set 6 | havre-saint-pierre
# Processing Record 35 of Set 6 | pevek
# Processing Record 36 of Set 6 | hobbs
# Processing Record 37 of Set 6 | padang
# Processing Record 38 of Set 6 | cockburn town
# Processing Record 39 of Set 6 | neon karlovasion
# Processing Record 40 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 6 | torbay
# Processing Record 42 of Set 6 | mana
# Processing Record 43 of Set 6 | gat
# Processing Record 44 of Set 6 | cayenne
# Processing Record 45 of Set 6 | scottsboro
# Processing Record 46 of Set 6 | sitka
# Processing Record 47 of Set 6 | salisbury
# Processing Record 48 of Set 6 | kaitong
# Processing Record 49 of Set 6 | fez
# Processing Record 50 of Set 6 | seoul
# Processing Record 1 of Set 7 | videira
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | najran
# Processing Record 4 of Set 7 | mackay
# Processing Record 5 of Set 7 | naze
# Processing Record 6 of Set 7 | pangnirtung
# Processing Record 7 of Set 7 | sorong
# Processing Record 8 of Set 7 | uzventis
# Processing Record 9 of Set 7 | klaksvik
# Processing Record 10 of Set 7 | yining
# Processing Record 11 of Set 7 | samoded
# Processing Record 12 of Set 7 | adrar
# Processing Record 13 of Set 7 | kumo
# Processing Record 14 of Set 7 | melville
# Processing Record 15 of Set 7 | leh
# Processing Record 16 of Set 7 | coquimbo
# Processing Record 17 of Set 7 | estevan
# Processing Record 18 of Set 7 | henties bay
# Processing Record 19 of Set 7 | sioux lookout
# Processing Record 20 of Set 7 | geraldton
# Processing Record 21 of Set 7 | ambon
# Processing Record 22 of Set 7 | itarema
# Processing Record 23 of Set 7 | svetlyy
# Processing Record 24 of Set 7 | zhigansk
# Processing Record 25 of Set 7 | kalmunai
# Processing Record 26 of Set 7 | payson
# Processing Record 27 of Set 7 | nome
# Processing Record 28 of Set 7 | tongzi
# Processing Record 29 of Set 7 | kropotkin
# Processing Record 30 of Set 7 | andros
# Processing Record 31 of Set 7 | jacareacanga
# Processing Record 32 of Set 7 | sturgeon falls
# Processing Record 33 of Set 7 | ostrovnoy
# Processing Record 34 of Set 7 | kidal
# Processing Record 35 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 7 | iguape
# Processing Record 37 of Set 7 | oskemen
# Processing Record 38 of Set 7 | coahuayana
# Processing Record 39 of Set 7 | sidrolandia
# Processing Record 40 of Set 7 | pailitas
# Processing Record 41 of Set 7 | bilibino
# Processing Record 42 of Set 7 | shar
# Processing Record 43 of Set 7 | puerto madryn
# Processing Record 44 of Set 7 | pontianak
# Processing Record 45 of Set 7 | mount darwin
# Processing Record 46 of Set 7 | macau
# Processing Record 47 of Set 7 | gelibolu
# Processing Record 48 of Set 7 | monrovia
# Processing Record 49 of Set 7 | rosario
# Processing Record 50 of Set 7 | partizanskoye
# Processing Record 1 of Set 8 | cidreira
# Processing Record 2 of Set 8 | akdepe
# Processing Record 3 of Set 8 | souillac
# Processing Record 4 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 8 | half moon bay
# Processing Record 6 of Set 8 | doka
# Processing Record 7 of Set 8 | cravo norte
# Processing Record 8 of Set 8 | vanderhoof
# Processing Record 9 of Set 8 | clearwater
# Processing Record 10 of Set 8 | vanimo
# Processing Record 11 of Set 8 | ust-koksa
# Processing Record 12 of Set 8 | castro
# Processing Record 13 of Set 8 | vyazemskiy
# Processing Record 14 of Set 8 | chunskiy
# Processing Record 15 of Set 8 | tuatapere
# Processing Record 16 of Set 8 | xining
# Processing Record 17 of Set 8 | kanigoro
# Processing Record 18 of Set 8 | maldonado
# Processing Record 19 of Set 8 | kamaishi
# Processing Record 20 of Set 8 | cedral
# Processing Record 21 of Set 8 | caravelas
# Processing Record 22 of Set 8 | inirida
# Processing Record 23 of Set 8 | ngunguru
# Processing Record 24 of Set 8 | ginda
# Processing Record 25 of Set 8 | sao gabriel da cachoeira
# Processing Record 26 of Set 8 | viedma
# Processing Record 27 of Set 8 | natal
# Processing Record 28 of Set 8 | koryukivka
# Processing Record 29 of Set 8 | premia de mar
# Processing Record 30 of Set 8 | arinos
# Processing Record 31 of Set 8 | tromso
# Processing Record 32 of Set 8 | buala
# Processing Record 33 of Set 8 | kedarnath
# City not found. Skipping...
# Processing Record 34 of Set 8 | lucapa
# Processing Record 35 of Set 8 | lianran
# Processing Record 36 of Set 8 | sao sebastiao do paraiso
# Processing Record 37 of Set 8 | athabasca
# Processing Record 38 of Set 8 | abalak
# Processing Record 39 of Set 8 | mount isa
# Processing Record 40 of Set 8 | nelson bay
# Processing Record 41 of Set 8 | kwinana
# Processing Record 42 of Set 8 | rutul
# Processing Record 43 of Set 8 | kings mountain
# Processing Record 44 of Set 8 | ondjiva
# Processing Record 45 of Set 8 | dashitou
# Processing Record 46 of Set 8 | nantucket
# Processing Record 47 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 8 | huarmey
# Processing Record 49 of Set 8 | bandarbeyla
# Processing Record 50 of Set 8 | andra
# Processing Record 1 of Set 9 | komsomolskiy
# Processing Record 2 of Set 9 | gallup
# Processing Record 3 of Set 9 | wabag
# Processing Record 4 of Set 9 | aykhal
# Processing Record 5 of Set 9 | sakata
# Processing Record 6 of Set 9 | vieques
# Processing Record 7 of Set 9 | aswan
# Processing Record 8 of Set 9 | olafsvik
# Processing Record 9 of Set 9 | khromtau
# Processing Record 10 of Set 9 | port lincoln
# Processing Record 11 of Set 9 | port hawkesbury
# Processing Record 12 of Set 9 | lashio
# Processing Record 13 of Set 9 | yangshe
# Processing Record 14 of Set 9 | koyelga
# Processing Record 15 of Set 9 | shenjiamen
# Processing Record 16 of Set 9 | siilinjarvi
# Processing Record 17 of Set 9 | lasa
# Processing Record 18 of Set 9 | los llanos de aridane
# Processing Record 19 of Set 9 | ahipara
# Processing Record 20 of Set 9 | luorong
# Processing Record 21 of Set 9 | charters towers
# Processing Record 22 of Set 9 | namatanai
# Processing Record 23 of Set 9 | lorengau
# Processing Record 24 of Set 9 | awbari
# Processing Record 25 of Set 9 | great yarmouth
# Processing Record 26 of Set 9 | kosa
# Processing Record 27 of Set 9 | beringovskiy
# Processing Record 28 of Set 9 | llangefni
# Processing Record 29 of Set 9 | yulara
# Processing Record 30 of Set 9 | namanga
# Processing Record 31 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 32 of Set 9 | saint paul
# Processing Record 33 of Set 9 | chuy
# Processing Record 34 of Set 9 | bonavista
# Processing Record 35 of Set 9 | constantine
# Processing Record 36 of Set 9 | san quintin
# Processing Record 37 of Set 9 | tubmanburg
# Processing Record 38 of Set 9 | illela
# Processing Record 39 of Set 9 | mehamn
# Processing Record 40 of Set 9 | waddan
# Processing Record 41 of Set 9 | nemuro
# Processing Record 42 of Set 9 | entre rios
# Processing Record 43 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 9 | griffith
# Processing Record 45 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 9 | afanasyevo
# City not found. Skipping...
# Processing Record 47 of Set 9 | midland
# Processing Record 48 of Set 9 | sur
# Processing Record 49 of Set 9 | vila
# Processing Record 50 of Set 9 | del rio
# Processing Record 1 of Set 10 | matara
# Processing Record 2 of Set 10 | tinskoy
# Processing Record 3 of Set 10 | salcininkai
# Processing Record 4 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 10 | laranjeiras do sul
# Processing Record 6 of Set 10 | samsun
# Processing Record 7 of Set 10 | bata
# Processing Record 8 of Set 10 | berlevag
# Processing Record 9 of Set 10 | dalbandin
# Processing Record 10 of Set 10 | opuwo
# Processing Record 11 of Set 10 | northam
# Processing Record 12 of Set 10 | salalah
# Processing Record 13 of Set 10 | san rafael del sur
# Processing Record 14 of Set 10 | jales
# Processing Record 15 of Set 10 | bolu
# Processing Record 16 of Set 10 | lusambo
# Processing Record 17 of Set 10 | murgab
# Processing Record 18 of Set 10 | pangody
# Processing Record 19 of Set 10 | avera
# Processing Record 20 of Set 10 | stornoway
# Processing Record 21 of Set 10 | charyshskoye
# Processing Record 22 of Set 10 | ormara
# Processing Record 23 of Set 10 | oksfjord
# Processing Record 24 of Set 10 | hasaki
# Processing Record 25 of Set 10 | shimanovsk
# Processing Record 26 of Set 10 | chanderi
# Processing Record 27 of Set 10 | sao filipe
# Processing Record 28 of Set 10 | mosquera
# Processing Record 29 of Set 10 | lubao
# Processing Record 30 of Set 10 | serebryanyy bor
# Processing Record 31 of Set 10 | black river
# Processing Record 32 of Set 10 | dingle
# Processing Record 33 of Set 10 | tshela
# Processing Record 34 of Set 10 | mitu
# Processing Record 35 of Set 10 | luwuk
# Processing Record 36 of Set 10 | kisaran
# Processing Record 37 of Set 10 | mountain home
# Processing Record 38 of Set 10 | kavaratti
# Processing Record 39 of Set 10 | yeniseysk
# Processing Record 40 of Set 10 | karratha
# Processing Record 41 of Set 10 | moose factory
# Processing Record 42 of Set 10 | ohangaron
# Processing Record 43 of Set 10 | marzuq
# Processing Record 44 of Set 10 | valpacos
# Processing Record 45 of Set 10 | iquique
# Processing Record 46 of Set 10 | namibe
# Processing Record 47 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 10 | asfi
# Processing Record 49 of Set 10 | masumbwe
# Processing Record 50 of Set 10 | shirokiy
# Processing Record 1 of Set 11 | hualmay
# Processing Record 2 of Set 11 | finote selam
# Processing Record 3 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 11 | parati
# Processing Record 5 of Set 11 | konispol
# Processing Record 6 of Set 11 | roald
# Processing Record 7 of Set 11 | piacabucu
# Processing Record 8 of Set 11 | kvitok
# Processing Record 9 of Set 11 | quatre cocos
# Processing Record 10 of Set 11 | divnogorsk
# Processing Record 11 of Set 11 | lagos
# Processing Record 12 of Set 11 | muisne
# Processing Record 13 of Set 11 | barcelona
# Processing Record 14 of Set 11 | mayo
# Processing Record 15 of Set 11 | mossendjo
# Processing Record 16 of Set 11 | albolote
# Processing Record 17 of Set 11 | lodja
# Processing Record 18 of Set 11 | itaituba
# Processing Record 19 of Set 11 | brae
# Processing Record 20 of Set 11 | kankan
# Processing Record 21 of Set 11 | ban nahin
# Processing Record 22 of Set 11 | alofi
# Processing Record 23 of Set 11 | uniao
# Processing Record 24 of Set 11 | lidzbark warminski
# Processing Record 25 of Set 11 | winslow
# Processing Record 26 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 11 | banff
# Processing Record 28 of Set 11 | ouadda
# Processing Record 29 of Set 11 | maues
# Processing Record 30 of Set 11 | pangai
# Processing Record 31 of Set 11 | ariquemes
# Processing Record 32 of Set 11 | slave lake
# Processing Record 33 of Set 11 | prince george
# Processing Record 34 of Set 11 | gizycko
# Processing Record 35 of Set 11 | bud
# Processing Record 36 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 11 | vao
# Processing Record 38 of Set 11 | nouakchott
# Processing Record 39 of Set 11 | nanzhang
# Processing Record 40 of Set 11 | arlit
# Processing Record 41 of Set 11 | cabinda
# Processing Record 42 of Set 11 | puerto pinasco
# City not found. Skipping...
# Processing Record 43 of Set 11 | queenstown
# Processing Record 44 of Set 11 | mananjary
# Processing Record 45 of Set 11 | port keats
# Processing Record 46 of Set 11 | kanniyakumari
# Processing Record 47 of Set 11 | aitape
# Processing Record 48 of Set 11 | turochak
# Processing Record 49 of Set 11 | nanortalik
# Processing Record 50 of Set 11 | beveren
# Processing Record 1 of Set 12 | santa maria
# Processing Record 2 of Set 12 | eureka
# Processing Record 3 of Set 12 | takaka
# Processing Record 4 of Set 12 | lakota
# Processing Record 5 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 6 of Set 12 | ferzikovo
# Processing Record 7 of Set 12 | mocuba
# Processing Record 8 of Set 12 | sorland
# Processing Record 9 of Set 12 | garowe
# Processing Record 10 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 12 | odweyne
# Processing Record 12 of Set 12 | harper
# Processing Record 13 of Set 12 | tabuk
# Processing Record 14 of Set 12 | cap malheureux
# Processing Record 15 of Set 12 | syasstroy
# Processing Record 16 of Set 12 | fortuna
# Processing Record 17 of Set 12 | andijon
# Processing Record 18 of Set 12 | saint-joseph
# Processing Record 19 of Set 12 | sterlibashevo
# Processing Record 20 of Set 12 | constitucion
# Processing Record 21 of Set 12 | quang ngai
# Processing Record 22 of Set 12 | yaan
# Processing Record 23 of Set 12 | owerri
# Processing Record 24 of Set 12 | staryy nadym
# Processing Record 25 of Set 12 | kingaroy
# Processing Record 26 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 12 | victoria point
# Processing Record 28 of Set 12 | alihe
# Processing Record 29 of Set 12 | nakatunguru
# Processing Record 30 of Set 12 | rockport
# Processing Record 31 of Set 12 | zwedru
# Processing Record 32 of Set 12 | narsaq
# Processing Record 33 of Set 12 | zlitan
# Processing Record 34 of Set 12 | sistranda
# Processing Record 35 of Set 12 | santa rosa
# Processing Record 36 of Set 12 | balti
# Processing Record 37 of Set 12 | panacan
# Processing Record 38 of Set 12 | feodosiya
# Processing Record 39 of Set 12 | jujuy
# City not found. Skipping...
# Processing Record 40 of Set 12 | burica
# City not found. Skipping...
# Processing Record 41 of Set 12 | aberdeen
# Processing Record 42 of Set 12 | north bend
# Processing Record 43 of Set 12 | pisco
# Processing Record 44 of Set 12 | labuhan
# Processing Record 45 of Set 12 | zherdevka
# Processing Record 46 of Set 12 | pemba
# Processing Record 47 of Set 12 | ust-tsilma
# Processing Record 48 of Set 12 | purranque
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vidim  56.4088  103.1106     37.53        93         100
# 1    Rio Grande -32.0350  -52.0986     56.95        79           0
# 2  Longyearbyen  78.2186   15.6401      6.64        61          20
# 3       Rikitea -23.1203 -134.9692     77.05        69           0
# 4      Lewiston  44.1003  -70.2148     45.39        38           0
# 5     Jamestown  42.0970  -79.2353     35.71        60           0
# 6      Hermanus -34.4187   19.2345     60.98        89         100
# 7     Fairbanks  64.8378 -147.7164     53.56        33           0
# 8   Clyde River  70.4692  -68.5914      3.43        92         100
# 9  Punta Arenas -53.1500  -70.9167     42.91        75          75
#
#    Wind Speed Country                 Date
# 0        7.25      RU  2022-04-29 02:14:27
# 1       10.22      BR  2022-04-29 02:14:28
# 2       14.97      SJ  2022-04-29 02:14:28
# 3       18.34      PF  2022-04-29 02:14:29
# 4       16.11      US  2022-04-29 02:11:18
# 5        3.44      US  2022-04-29 02:13:31
# 6        6.64      ZA  2022-04-29 02:14:29
# 7        4.61      US  2022-04-29 02:14:30
# 8        4.61      CA  2022-04-29 02:09:53
# 9       26.46      CL  2022-04-29 02:09:53

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1651199348.606689

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
#plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                   Phan Thiet
# Lat                       10.9333
# Lng                         108.1
# Max Temp                    76.91
# Humidity                       93
# Cloudiness                    100
# Wind Speed                   6.64
# Country                        VN
# Date          2022-04-29 02:12:15
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 547    False
# 548     True
# 549    False
# 550     True
# 551    False
# Name: Lat, Length: 552, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vidim  56.4088  103.1106     37.53        93         100
# 2  Longyearbyen  78.2186   15.6401      6.64        61          20
# 4      Lewiston  44.1003  -70.2148     45.39        38           0
# 5     Jamestown  42.0970  -79.2353     35.71        60           0
# 7     Fairbanks  64.8378 -147.7164     53.56        33           0
#
#    Wind Speed Country                 Date
# 0        7.25      RU  2022-04-29 02:14:27
# 2       14.97      SJ  2022-04-29 02:14:28
# 4       16.11      US  2022-04-29 02:11:18
# 5        3.44      US  2022-04-29 02:13:31
# 7        4.61      US  2022-04-29 02:14:30

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % CLoudiness', '% CLoudiness',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/1c/hpx57sqs2rq0t65xphc2dz8c0000gn/T/ipykernel_39516/2287817461.py in <module>
#       4 import requests
#       5 # Import the API key.
# ----> 6 from config import g_key
#
# ImportError: cannot import name 'g_key' from 'config' (/Users/jlinhuang/Desktop/bootcamp/World_Weather_Analysis/config.py)
